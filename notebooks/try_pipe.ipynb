# %% [markdown]
# #### Концепция библиотеки подразумевает создание нескольких моделей и сравнение их результатов, но самый простой вариант использования - собственное использование конкретной модели из имеющихся .

# %%
# %load_ext autoreload
# %autoreload 2

from sys import path 
path.append('../')

import warnings
warnings.filterwarnings(action='ignore')

# %%
import pandas as pd

from sklearn.model_selection import train_test_split

# %%
initial_data = pd.read_csv('../data/raw/breast_cancer_wisconsin/data.csv')

# %%
initial_data.sample(5)
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 62     858986         M        14.25         22.15           96.42      645.7
# 367   9011495         B        12.21         18.02           78.31      458.4
# 202    878796         M        23.29         26.67          158.90     1685.0
# 9    84501001         M        12.46         24.04           83.97      475.9
# 419    906290         B        11.16         21.41           70.95      380.3
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 62           0.10490           0.20080        0.213500              0.08653
# 367          0.09231           0.07175        0.043920              0.02027
# 202          0.11410           0.20840        0.352300              0.16200
# 9            0.11860           0.23960        0.227300              0.08543
# 419          0.10180           0.05978        0.008955              0.01076
#
# ...

# %% [markdown]
# #### Препроцесс

# %%
preprocessed_data = initial_data.drop(['id', 'Unnamed: 32'], axis=1)

# %% [markdown]
# #### Разделение на фичи и таргет

# %%
X, y = preprocessed_data.drop('diagnosis', axis=1), preprocessed_data.loc[:, 'diagnosis'].map({'M':1,'B':0})

# %%
X.describe()
# Out:
#        radius_mean  texture_mean  perimeter_mean    area_mean  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# %%
from ABC.core.pipe import Pipe 
from ABC.core.data import Data
from ABC.zoo.transform.standard_scaler import TransformStandardScaler
from ABC.zoo.model.logistic_regression import ModelLogisticRegression

# %%
my_pipe = Pipe([
    TransformStandardScaler(),
    ModelLogisticRegression()
])

# %%
X_data = Data(train=X.copy(), validation=None)
y_data = Data(train=y.copy(), validation=None)

my_pipe.fit(X_data, y_data)

# %%
my_pipe
# Out:
# TransformStandardScaler: 140585933997072
#   └ModelLogisticRegression: 140585969275408
#     └End

# %% [markdown]
# #### Сохранение модели

# %%
from ABC.core.storage import Storage

# %%
Storage.save(my_pipe, 'my_test_pipe')
# Out:
# Сохранение:
# 	Текущая директория: /home/alice/Documents/auto_bin_classification/notebooks
# 	Корень базы данных: .
# 	Хранилище/Подхранилище: .

# %% [markdown]
# #### Загрузка модели

# %%
my_loaded_pipe = Storage.load('my_test_pipe')
# Out:
# Загрузка:
# 	Загрузка из: my_test_pipe.pickle
# Объект был сохранен: 2020-11-22 17:58:15.197026
# Описание: отсутствует

# %%
my_loaded_pipe
# Out:
# TransformStandardScaler: 140585917070608
#   └ModelLogisticRegression: 140585917068496
#     └End

# %%
from sklearn.metrics import precision_score, recall_score, accuracy_score
from sklearn.metrics import classification_report

# %%
print(classification_report(my_pipe.predict(X_test), y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99        41
#            1       0.94      1.00      0.97        16
#
#     accuracy                           0.98        57
#    macro avg       0.97      0.99      0.98        57
# weighted avg       0.98      0.98      0.98        57
